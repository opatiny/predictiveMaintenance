# %% [markdown]
# # Plot data, compare various signals and test basic processing

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# ## Test `plotSignal`
# Plot a specific signal.

# %%
from utils.plotSignal import plotSignal

current_folder = os.getcwd()
print(current_folder)

folderPath = "../../data/Mecatis/Warmup_Mecatis_03_02_25/"
filename = "stSigAxCurrentB.csv"

filePath = current_folder + "/" + folderPath + filename


plotSignal(filePath)
# Out:
# /Users/opatiny/git/opatiny/predictiveMaintenance/src/notebooks
# in getYLabel
# /Users/opatiny/git/opatiny/predictiveMaintenance/src/utils/../../data/signalsDescription.csv

# %% [markdown]
# ## Test `addSeries`
#
# Plot multiple series on one graph
